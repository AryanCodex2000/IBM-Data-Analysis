# %%
import os
import numpy as np 
import pandas as pd
import sklearn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/kaggle/working'

# %%
ibm = pd.read_csv("/kaggle/input/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
ibm.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
ibm.tail(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
ibm.shape
print("The number of rows in the dataset are:-",ibm.shape[0] )
print("The number of columns in the dataset are:-",ibm.shape[1])
# Out:
# The number of rows in the dataset are:- 1470
# The number of columns in the dataset are:- 35

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
ibm.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
''' 'BusinessTravel', 'DailyRate', 'DistanceFromHome', 'Education', 'JobLevel', 'MonthlyRate', 'NumCompaniesWorked', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'YearsWithCurrManager' '''
# Out:
# " 'BusinessTravel', 'DailyRate', 'DistanceFromHome', 'Education', 'JobLevel', 'MonthlyRate', 'NumCompaniesWorked', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'YearsWithCurrManager' "

# %%
ibm['JobLevel'].head(9)
# Out:
# 0    2
# 1    2
# 2    1
# 3    1
# 4    1
# 5    1
# 6    1
# 7    1
# 8    3
# Name: JobLevel, dtype: int64

# %%
ibm['JobRole'].head(9)
# Out:
# 0           Sales Executive
# 1        Research Scientist
# 2     Laboratory Technician
# 3        Research Scientist
# 4     Laboratory Technician
# 5     Laboratory Technician
# 6     Laboratory Technician
# 7     Laboratory Technician
# 8    Manufacturing Director
# Name: JobRole, dtype: object

# %%
ibm['NumCompaniesWorked'].head(9)
# Out:
# 0    8
# 1    1
# 2    6
# 3    1
# 4    9
# 5    0
# 6    4
# 7    1
# 8    0
# Name: NumCompaniesWorked, dtype: int64

# %%
ibm['RelationshipSatisfaction'].head(9)
# Out:
# 0    1
# 1    4
# 2    2
# 3    3
# 4    4
# 5    3
# 6    1
# 7    2
# 8    2
# Name: RelationshipSatisfaction, dtype: int64

# %%
ibm.drop(columns=['BusinessTravel', 'DailyRate', 'DistanceFromHome', 'Education', 'JobLevel', 'MonthlyRate', 'NumCompaniesWorked', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'YearsWithCurrManager'], inplace = True)

# %%
ibm.shape
# Out:
# (1470, 24)

# %%
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion'],
#       dtype='object')

# %%
ibm.dtypes
# Out:
# Age                         int64
# Attrition                  object
# Department                 object
# EducationField             object
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                     object
# HourlyRate                  int64
# JobInvolvement              int64
# JobRole                    object
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# Over18                     object
# OverTime                   object
# PercentSalaryHike           int64
# PerformanceRating           int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# dtype: object

# %%
ibm['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
ibm['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
ibm['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
ibm['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
ibm['EnvironmentSatisfaction'].value_counts()
# Out:
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64

# %%
ibm['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
ibm['MonthlyIncome'].value_counts()
# Out:
# MonthlyIncome
# 2342     4
# 6142     3
# 2741     3
# 2559     3
# 2610     3
#         ..
# 7104     1
# 2773     1
# 19513    1
# 3447     1
# 4404     1
# Name: count, Length: 1349, dtype: int64

# %%
ibm.drop(columns=['JobInvolvement', 'HourlyRate', 'EmployeeCount'], inplace = True)

# %%
ibm.shape
# Out:
# (1470, 21)

# %%
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion'],
#       dtype='object')

# %%
ibm.nunique()
# Out:
# Age                          43
# Attrition                     2
# Department                    3
# EducationField                6
# EmployeeNumber             1470
# EnvironmentSatisfaction       4
# Gender                        2
# JobRole                       9
# JobSatisfaction               4
# MaritalStatus                 3
# MonthlyIncome              1349
# Over18                        1
# OverTime                      2
# PercentSalaryHike            15
# PerformanceRating             2
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# WorkLifeBalance               4
# YearsAtCompany               37
# YearsInCurrentRole           19
# YearsSinceLastPromotion      16
# dtype: int64

# %%
ibm.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# Department                 0
# EducationField             0
# EmployeeNumber             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# Over18                     0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
ibm['Attrition'].value_counts().plot(kind='bar', color=['#4285F4', '#EA4335'])
plt.title('Attrition Count')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(ibm['Age'], bins=20, color='#4285F4', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10,6))
ibm['Department'].value_counts().plot(kind='barh', color='#34A8A8')
plt.title('Department Distribution')
plt.xlabel('Count')
plt.ylabel('Department')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--',alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(ibm['MonthlyIncome'], bins=30, color='#FB8C00', edgecolor='black')
plt.title('Monthly Income Distribution')
plt.xlabel('Monthly Income')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(6,4))
ibm['Gender'].value_counts().plot(kind='bar', color=['#A855F7', '#6C63FF'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.countplot(data=ibm, x='Department', hue='Attrition')
plt.title("Attrition Count by Department")
plt.xticks(rotation=0)
plt.show()

# %%
### Average Monthly Income by job role
plt.figure(figsize=(20,8))
ibm.groupby('JobRole')['MonthlyIncome'].mean().plot(kind='bar')
plt.title("Average Monthly Income by Job Role")
plt.ylabel("Average Monthly Income")
plt.xticks(rotation=0)
plt.show()

# %%
sns.countplot(data=ibm, x='Gender', hue='OverTime')
plt.title("Employee Count by Gender and OverTime")
plt.show()

# %%
plt.figure(figsize=(12,15))
ibm.groupby('MaritalStatus')['YearsAtCompany'].mean().plot(kind='bar')
plt.title("Average Years at the Company by Marital Status")
plt.ylabel("Years at company")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=ibm, x='WorkLifeBalance', y='JobSatisfaction')
plt.title('Job Satisfaction vs Work Life Balance')
plt.show()

# %%
ibm['Attrition'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Attrition Distribution")
plt.ylabel("")
plt.show()

# %%
ibm['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
ibm['OverTime'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("OverTime Distribution")
plt.ylabel("")
plt.show()

# %%
ibm['Department'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Department Distribution")
plt.ylabel("")
plt.show()

# %%
ibm['EducationField'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Education Field Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=ibm, x='YearsAtCompany', y='MonthlyIncome')
plt.title("Monthly Income vs Years at Company")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(data=ibm, x='TotalWorkingYears', y='PercentSalaryHike')
plt.title("Total Working Years vs Percent Salary Hike")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(data=ibm, x='WorkLifeBalance', y='JobSatisfaction')
plt.title("Job Satisfaction vs Work Life Balance")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(data=ibm, x='YearsInCurrentRole', y='YearsAtCompany')
plt.title("Years at company vs years in current role")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(data=ibm, x='PerformanceRating', y='TrainingTimesLastYear')
plt.title("Training Times vs Performance Rating")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
### Correlation Heatmap of Numerical Features
import numpy as np
import seaborn as sns

corr = ibm[['Age', 'MonthlyIncome', 'PercentSalaryHike', 'TotalWorkingYears',
           'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
           'YearsInCurrentRole', 'YearsSinceLastPromotion']].corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
pivot = ibm.pivot_table(index='Department', columns='JobRole', values='MonthlyIncome', aggfunc=np.mean)
sns.heatmap(pivot, cmap='YlGnBu', annot=True, fmt='.0f')
plt.title("Avg Monthly Income by Department & Job Role")
plt.show()
# Out:
# /tmp/ipykernel_13/3886209849.py:1: FutureWarning: The provided callable <function mean at 0x79f324c8d580> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot = ibm.pivot_table(index='Department', columns='JobRole', values='MonthlyIncome', aggfunc=np.mean)
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
pivot = ibm.pivot_table(index='MaritalStatus', columns='Gender', values='YearsAtCompany', aggfunc=np.mean)
sns.heatmap(pivot, annot=True, cmap='Blues')
plt.title("Avg Years at Company by Marital Status and Gender")
plt.show()
# Out:
# /tmp/ipykernel_13/1495050305.py:1: FutureWarning: The provided callable <function mean at 0x79f324c8d580> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot = ibm.pivot_table(index='MaritalStatus', columns='Gender', values='YearsAtCompany', aggfunc=np.mean)

# %%
pivot = ibm.pivot_table(index='WorkLifeBalance', columns='EnvironmentSatisfaction', values='JobSatisfaction', aggfunc=np.mean)
sns.heatmap(pivot, annot=True, cmap='coolwarm')
plt.title("Avg Job Satisfaction by WorkLifeBalance and EnvironmentSatisfaction")
plt.show()
# Out:
# /tmp/ipykernel_13/2280664235.py:1: FutureWarning: The provided callable <function mean at 0x79f324c8d580> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot = ibm.pivot_table(index='WorkLifeBalance', columns='EnvironmentSatisfaction', values='JobSatisfaction', aggfunc=np.mean)
